# %%
import pandas as pd
data = pd.read_csv("students.csv")
data.head()
# Out:
#    Student_ID   Name  Age  Marks_Math  Marks_Science
# 0           1    Ali   18          60             70
# 1           2   Sara   19          55             80
# 2           3  Ahmed   18          45             65
# 3           4   Noor   20          72             85
# 4           5  Usman   21          50             60

# %%
data.info()
data.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     10 non-null     int64
#  1   Name           10 non-null     object
#  2   Age            10 non-null     int64
#  3   Marks_Math     10 non-null     int64
#  4   Marks_Science  10 non-null     int64
# dtypes: int64(4), object(1)
# memory usage: 532.0+ bytes
#        Student_ID        Age  Marks_Math  Marks_Science
# count    10.00000  10.000000   10.000000      10.000000
# mean      5.50000  19.700000   60.500000      75.000000
# std       3.02765   1.337494   13.858411      14.290634
# min       1.00000  18.000000   40.000000      55.000000
# 25%       3.25000  19.000000   51.250000      62.750000
# 50%       5.50000  19.500000   59.000000      75.000000
# 75%       7.75000  20.750000   70.250000      87.250000
# max      10.00000  22.000000   82.000000      95.000000

# %%
data['Marks_Math'].mean()
data['Marks_Science'].max()
# Out:
# np.int64(95)

# %%
import matplotlib.pyplot as plt
plt.bar(data['Student_ID'], data['Marks_Math'])
plt.show()
