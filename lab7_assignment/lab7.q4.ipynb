# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

temp = 20 + np.sin(np.linspace(0, 10*np.pi, 400))

window = 30
X, y = [], []
for i in range(len(temp) - window):
    X.append(temp[i:i+window])
    y.append(temp[i+window])

X = np.array(X).reshape(-1, window, 1)
y = np.array(y)

model = Sequential([
    SimpleRNN(60),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=10)

pred = model.predict(X)

plt.plot(y, label="Actual")
plt.plot(pred, label="Predicted")
plt.legend()
plt.show()
# Out:
# Epoch 1/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 384.4408
# Epoch 2/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 310.5340
# Epoch 3/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 246.6606
# Epoch 4/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 190.6434
# Epoch 5/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 154.2894
# Epoch 6/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 127.4696
# Epoch 7/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 104.8898
# Epoch 8/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 89.0712
# Epoch 9/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 76.8267
# Epoch 10/10
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 67.0011
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step
