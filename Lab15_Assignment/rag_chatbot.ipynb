# %%
from langchain_community.llms import Ollama
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from langchain_community.llms import Ollama
#       2 from langchain_community.document_loaders import TextLoader
# ----> 3 from langchain.text_splitter import RecursiveCharacterTextSplitter
#       4 from langchain_community.embeddings import OllamaEmbeddings
#       5 from langchain_community.vectorstores import FAISS
#
# ModuleNotFoundError: No module named 'langchain.text_splitter'

# %%
# !pip show langchain
# Out:
# Name: langchain
# Version: 1.2.3
# Summary: Building applications with LLMs through composability
# Home-page: https://docs.langchain.com/
# Author:
# Author-email:
# License: MIT
# Location: C:\Users\AL MAKKAH\Documents\MyProjects\myenv\Lib\site-packages
# Requires: langchain-core, langgraph, pydantic
# Required-by:

# %%
# !pip install -U langchain langchain-community langchain-core faiss-cpu ollama
# Out:
# Requirement already satisfied: langchain in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (1.2.3)
# Requirement already satisfied: langchain-community in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-core in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (1.2.7)
# Requirement already satisfied: faiss-cpu in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (1.13.2)
# Collecting ollama
#   Downloading ollama-0.6.1-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: langgraph<1.1.0,>=1.0.2 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain) (1.0.5)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (0.6.2)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-core) (0.13.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<4.0.0,>=2.1.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.0.1)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (1.0.5)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (0.3.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph<1.1.0,>=1.0.2->langchain) (3.6.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph<1.1.0,>=1.0.2->langchain) (1.12.1)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.11.5)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core) (0.25.0)
# Requirement already satisfied: anyio in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (4.11.0)
# Requirement already satisfied: certifi in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.0.9)
# Requirement already satisfied: idna in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (1.0.1)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (2.0.45)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=2.1.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-community) (2.3.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core) (2.5.0)
# Requirement already satisfied: greenlet>=1 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\al makkah\documents\myprojects\myenv\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.1.0,>=1.0.2->langchain) (1.3.1)
# Downloading ollama-0.6.1-py3-none-any.whl (14 kB)
# Installing collected packages: ollama
# Successfully installed ollama-0.6.1
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.llms import Ollama
from langchain_community.document_loaders import TextLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import FAISS

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
from langchain_community.llms import Ollama
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_community.embeddings import OllamaEmbeddings
from langchain_community.vectorstores import FAISS

from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough

# %%
loader = TextLoader("data/sample_docs.txt")
documents = loader.load()

documents
# Out:
# [Document(metadata={'source': 'data/sample_docs.txt'}, page_content='Artificial Intelligence is the simulation of human intelligence.\nMachine Learning is a subset of AI.\nDeep Learning uses neural networks.')]

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50
)

docs = text_splitter.split_documents(documents)
len(docs)
# Out:
# 1

# %%
embeddings = OllamaEmbeddings(model="llama2")

vectorstore = FAISS.from_documents(docs, embeddings)

retriever = vectorstore.as_retriever()
# Out:
# C:\Users\AL MAKKAH\AppData\Local\Temp\ipykernel_15336\2925823613.py:1: LangChainDeprecationWarning: The class `OllamaEmbeddings` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaEmbeddings``.
#   embeddings = OllamaEmbeddings(model="llama2")

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", "Answer the question using the provided context only."),
        ("user", "Context:\n{context}\n\nQuestion:\n{question}")
    ]
)

# %%
llm = Ollama(model="llama2")
output_parser = StrOutputParser()

rag_chain = (
    {
        "context": retriever,
        "question": RunnablePassthrough()
    }
    | prompt
    | llm
    | output_parser
)
# Out:
# C:\Users\AL MAKKAH\AppData\Local\Temp\ipykernel_15336\2309166164.py:1: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the `langchain-ollama package and should be used instead. To use it run `pip install -U `langchain-ollama` and import as `from `langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama2")

# %%
rag_chain.invoke("What is Artificial Intelligence?")
# Out:
# 'Based on the provided context, the answer to the question "What is Artificial Intelligence?" can be inferred as:\n\nArtificial Intelligence (AI) is the simulation of human intelligence.'
